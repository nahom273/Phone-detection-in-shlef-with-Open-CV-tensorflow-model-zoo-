# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'nt':
            # !mkdir {path}

# %%
if os.name =="nt":
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in a:\projects\object detection\tfodcourse\tfod\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'],'research','object_detection')):
                      # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow\models'...
# Updating files:  35% (1314/3709)
# Updating files:  36% (1336/3709)
# Updating files:  37% (1373/3709)
# Updating files:  38% (1410/3709)
# Updating files:  39% (1447/3709)
# Updating files:  40% (1484/3709)
# Updating files:  41% (1521/3709)
# Updating files:  42% (1558/3709)
# Updating files:  43% (1595/3709)
# Updating files:  44% (1632/3709)
# Updating files:  45% (1670/3709)
# Updating files:  46% (1707/3709)
# Updating files:  47% (1744/3709)
# Updating files:  48% (1781/3709)
# Updating files:  49% (1818/3709)
# Updating files:  50% (1855/3709)
# Updating files:  51% (1892/3709)
# Updating files:  52% (1929/3709)
# Updating files:  53% (1966/3709)
# Updating files:  54% (2003/3709)
# Updating files:  55% (2040/3709)
# Updating files:  56% (2078/3709)
# Updating files:  57% (2115/3709)
# Updating files:  58% (2152/3709)
# Updating files:  59% (2189/3709)
# Updating files:  60% (2226/3709)
# Updating files:  61% (2263/3709)
# Updating files:  62% (2300/3709)
# Updating files:  63% (2337/3709)
# Updating files:  63% (2349/3709)
# Updating files:  64% (2374/3709)
# Updating files:  65% (2411/3709)
# Updating files:  66% (2448/3709)
# Updating files:  67% (2486/3709)
# Updating files:  68% (2523/3709)
# Updating files:  69% (2560/3709)
# Updating files:  70% (2597/3709)
# Updating files:  71% (2634/3709)
# Updating files:  72% (2671/3709)
# Updating files:  73% (2708/3709)
# Updating files:  74% (2745/3709)
# Updating files:  75% (2782/3709)
# Updating files:  76% (2819/3709)
# Updating files:  77% (2856/3709)
# Updating files:  78% (2894/3709)
# Updating files:  79% (2931/3709)
# Updating files:  80% (2968/3709)
# Updating files:  81% (3005/3709)
# Updating files:  82% (3042/3709)
# Updating files:  83% (3079/3709)
# Updating files:  84% (3116/3709)
# Updating files:  85% (3153/3709)
# Updating files:  85% (3185/3709)
# Updating files:  86% (3190/3709)
# Updating files:  87% (3227/3709)
# Updating files:  88% (3264/3709)
# Updating files:  89% (3302/3709)
# Updating files:  90% (3339/3709)
# Updating files:  91% (3376/3709)
# Updating files:  92% (3413/3709)
# Updating files:  93% (3450/3709)
# Updating files:  94% (3487/3709)
# Updating files:  95% (3524/3709)
# Updating files:  96% (3561/3709)
# Updating files:  97% (3598/3709)
# Updating files:  98% (3635/3709)
# Updating files:  99% (3672/3709)
# Updating files: 100% (3709/3709)
# Updating files: 100% (3709/3709), done.

# %%
if os.name == 'nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
#         1 file(s) moved.
#         1 file(s) copied.
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\setuptools\command\easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# object_detection.core.__pycache__.densepose_ops.cpython-311: module references __file__
# object_detection.core.__pycache__.preprocessor.cpython-311: module MAY be using inspect.stack
# object_detection.utils.__pycache__.autoaugment_utils.cpython-311: module MAY be using inspect.stack
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-0.0.2.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-0.0.2.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-0.0.3.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-0.0.3.dev0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-0.0.3.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-0.0.3.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.1.0.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.1.0.dev1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.1.0.dev2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.1.0.dev2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.2.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.2.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.6.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.6.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.7.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.7.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.7.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.7.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.11.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.11.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.12.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.12.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.13.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.13.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.13.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.13.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.14.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.14.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.14.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.14.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.15.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.15.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: models-official-2.16.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: official-2.16.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-0.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.15.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.16.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.17.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.18.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.19.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.20.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.21.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.22.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.23.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.24.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.25.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.26.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.27.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.28.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.29.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.29.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.30.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.30.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.31.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.31.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.32.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.32.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.33.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.33.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.33.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.34.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.34.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.34.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0rc8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.35.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.36.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.37.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.38.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.38.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.39.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.39.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.39.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.40.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.40.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.40.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.41.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.41.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.41.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.42.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.42.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.42.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.43.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.43.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.43.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.44.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.44.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.45.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.45.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.46.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.46.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.47.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.48.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.48.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.48.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.49.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.49.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.49.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.50.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.50.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.50.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.51.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.51.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.52.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.52.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.52.0rc4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.52.0rc5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.52.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.53.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.53.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.53.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.54.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.54.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.54.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.55.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.55.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.55.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.55.1rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: beam-2.55.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.7.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.7.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.8.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.8.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.9.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: python3-1.10.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\setuptools\installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#   warnings.warn(
# WARNING: The wheel package is not available.
# WARNING: The wheel package is not available.
# a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# ...
# Best match: optree 0.11.0
# Processing optree-0.11.0-cp311-cp311-win_amd64.whl
# Installing optree-0.11.0-cp311-cp311-win_amd64.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding optree 0.11.0 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\optree-0.11.0-py3.11-win-amd64.egg
# Searching for h5py
# Reading https://pypi.org/simple/h5py/
# Downloading https://files.pythonhosted.org/packages/d8/5e/b7b83cfe60504cc4d24746aed04353af7ea8ec104e597e5ae71b8d0390cb/h5py-3.11.0-cp311-cp311-win_amd64.whl#sha256=083e0329ae534a264940d6513f47f5ada617da536d8dccbafc3026aefc33c90e
# Best match: h5py 3.11.0
# Processing h5py-3.11.0-cp311-cp311-win_amd64.whl
# Installing h5py-3.11.0-cp311-cp311-win_amd64.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding h5py 3.11.0 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\h5py-3.11.0-py3.11-win-amd64.egg
# Searching for namex
# Reading https://pypi.org/simple/namex/
# Downloading https://files.pythonhosted.org/packages/73/59/7854fbfb59f8ae35483ce93493708be5942ebb6328cd85b3a609df629736/namex-0.0.8-py3-none-any.whl#sha256=7ddb6c2bb0e753a311b7590f84f6da659dd0c05e65cb89d519d54c0a250c0487
# Best match: namex 0.0.8
# Processing namex-0.0.8-py3-none-any.whl
# Installing namex-0.0.8-py3-none-any.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding namex 0.0.8 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\namex-0.0.8-py3.11.egg
# Searching for rich
# Reading https://pypi.org/simple/rich/
# Downloading https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl#sha256=4edbae314f59eb482f54e9e30bf00d33350aaa94f4bfcd4e9e3110e64d0d7222
# Best match: rich 13.7.1
# Processing rich-13.7.1-py3-none-any.whl
# Installing rich-13.7.1-py3-none-any.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding rich 13.7.1 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\rich-13.7.1-py3.11.egg
# Searching for absl-py
# Reading https://pypi.org/simple/absl-py/
# Downloading https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl#sha256=526a04eadab8b4ee719ce68f204172ead1027549089702d99b9059f129ff1308
# Best match: absl-py 2.1.0
# Processing absl_py-2.1.0-py3-none-any.whl
# Installing absl_py-2.1.0-py3-none-any.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding absl-py 2.1.0 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\absl_py-2.1.0-py3.11.egg
# Searching for tensorflow-io-gcs-filesystem==0.31.0
# Reading https://pypi.org/simple/tensorflow-io-gcs-filesystem/
# Downloading https://files.pythonhosted.org/packages/ac/4e/9566a313927be582ca99455a9523a097c7888fc819695bdc08415432b202/tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl#sha256=4bb37d23f21c434687b11059cb7ffd094d52a7813368915ba1b7057e3c16e414
# Best match: tensorflow-io-gcs-filesystem 0.31.0
# Processing tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl
# Installing tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding tensorflow-io-gcs-filesystem 0.31.0 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg
# Searching for tf-keras>=2.16.0
# Reading https://pypi.org/simple/tf-keras/
# Downloading https://files.pythonhosted.org/packages/75/aa/cf09f8956d4f276f655b13674e15d8d6015fd832f9689aa9ff2a515781ab/tf_keras-2.16.0-py3-none-any.whl#sha256=b2ad0541fa7d9e92c4b7a1b96593377afb58aaff374299a6ca6be1a42f51d899
# Best match: tf-keras 2.16.0
# Processing tf_keras-2.16.0-py3-none-any.whl
# Installing tf_keras-2.16.0-py3-none-any.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding tf-keras 2.16.0 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_keras-2.16.0-py3.11.egg
# Searching for tensorflow~=2.16.1
# Reading https://pypi.org/simple/tensorflow/
# Downloading https://files.pythonhosted.org/packages/e4/14/d795bb156f8cc10eb1dcfe1332b7dbb8405b634688980aa9be8f885cc888/tensorflow-2.16.1-cp311-cp311-win_amd64.whl#sha256=093573a8eb93ef9511e7015b8de9659ed27156f2f05e6d1211f8f4cb76407ee1
# Best match: tensorflow 2.16.1
# Processing tensorflow-2.16.1-cp311-cp311-win_amd64.whl
# Installing tensorflow-2.16.1-cp311-cp311-win_amd64.whl to a:\projects\object detection\tfodcourse\tfod\lib\site-packages
# Adding tensorflow 2.16.1 to easy-install.pth file
#
# Installed a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow-2.16.1-py3.11-win-amd64.egg
# Searching for tensorflow-text~=2.16.1
# Reading https://pypi.org/simple/tensorflow-text/
# Obtaining file:///A:/Projects/Object%20Detection/TFODCourse/Tensorflow/models/research/slim
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six in a:\projects\object detection\tfodcourse\tfod\lib\site-packages (from slim==0.1) (1.16.0)
# Requirement already satisfied: tf-slim>=1.1 in a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_slim-1.1.0-py3.11.egg (from slim==0.1) (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in a:\projects\object detection\tfodcourse\tfod\lib\site-packages\absl_py-2.1.0-py3.11.egg (from tf-slim>=1.1->slim==0.1) (2.1.0)
# Building wheels for collected packages: slim
#   Building editable for slim (pyproject.toml): started
#   Building editable for slim (pyproject.toml): finished with status 'done'
#   Created wheel for slim: filename=slim-0.1-0.editable-py3-none-any.whl size=2670 sha256=9eec17cf963e307a6201b6e31049e17f82cf8b696654b03d4bb04746b3fb0b86
#   Stored in directory: C:\Users\12402\AppData\Local\Temp\pip-ephem-wheel-cache-a470sa7u\wheels\06\df\21\4cc68bfb53e21c2c21b197957009bdda81ef61753eec2a4e8a
# Successfully built slim
# Installing collected packages: slim
# Successfully installed slim-0.1
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\absl_py-2.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\apache_beam-2.56.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\cython-3.0.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\h5py-3.11.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\keras-3.3.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\lvis-0.5.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\matplotlib-3.9.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\ml_dtypes-0.4.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\namex-0.0.8-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\object_detection-0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\optree-0.11.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pandas-2.2.2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pillow-10.3.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\portalocker-2.8.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pycocotools-2.0.7-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pyparsing-2.4.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\regex-2024.5.15-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\rich-13.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\sacrebleu-2.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\scipy-1.14.0rc1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tabulate-0.9.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow-2.16.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow_io-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_keras-2.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_models_official-2.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_slim-1.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
# !protoc --version

# !cd Tensorflow/protoc/include/google/protobuf && protoc --python_out=. *.proto

# !cd 
# !protoc --python_out=. *.proto
# !pip install protobuf==3.20.*
# Out:
# libprotoc 3.15.6
# google/protobuf/any.proto:154:10: "google.protobuf.Any.type_url" is already defined in file "any.proto".
# google/protobuf/any.proto:157:9: "google.protobuf.Any.value" is already defined in file "any.proto".
# google/protobuf/any.proto:125:9: "google.protobuf.Any" is already defined in file "any.proto".
# google/protobuf/type.proto:35:1: Import "google/protobuf/any.proto" was not found or had errors.
# google/protobuf/type.proto:178:3: "google.protobuf.Any" seems to be defined in "any.proto", which is not imported by "google/protobuf/type.proto".  To use it here, please add the necessary import.
# api.proto:36:1: Import "google/protobuf/type.proto" was not found or had errors.
# api.proto:63:12: "Option" is not defined.
# api.proto:96:3: "Syntax" is not defined.
# api.proto:117:12: "Option" is not defined.
# api.proto:120:3: "Syntax" is not defined.
# a:\Projects\Object Detection\TFODCourse
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/162.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/162.1 kB ? eta -:--:--
#    ------- ------------------------------- 30.7/162.1 kB 217.9 kB/s eta 0:00:01
#    --------- ----------------------------- 41.0/162.1 kB 245.8 kB/s eta 0:00:01
#    ------------------------------------ - 153.6/162.1 kB 706.2 kB/s eta 0:00:01
#    -------------------------------------- 162.1/162.1 kB 693.6 kB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# Successfully installed protobuf-3.20.3
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\absl_py-2.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\apache_beam-2.56.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\cython-3.0.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\h5py-3.11.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\keras-3.3.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\lvis-0.5.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\matplotlib-3.9.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\namex-0.0.8-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\object_detection-0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\optree-0.11.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pandas-2.2.2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pillow-10.3.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\portalocker-2.8.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pycocotools-2.0.7-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\pyparsing-2.4.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\regex-2024.5.15-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\rich-13.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\sacrebleu-2.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\scipy-1.14.0rc1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tabulate-0.9.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow-2.16.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow_io-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tensorflow_io_gcs_filesystem-0.31.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_keras-2.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_models_official-2.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at a:\projects\object detection\tfodcourse\tfod\lib\site-packages\tf_slim-1.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.56.0 requires cloudpickle~=2.2.1, which is not installed.
# apache-beam 2.56.0 requires crcmod<2.0,>=1.7, which is not installed.
# apache-beam 2.56.0 requires dill<0.3.2,>=0.3.1.1, which is not installed.
# apache-beam 2.56.0 requires fastavro<2,>=0.23.6, which is not installed.
# apache-beam 2.56.0 requires fasteners<1.0,>=0.3, which is not installed.
# apache-beam 2.56.0 requires hdfs<3.0.0,>=2.1.0, which is not installed.
# apache-beam 2.56.0 requires httplib2<0.23.0,>=0.8, which is not installed.
# apache-beam 2.56.0 requires js2py<1,>=0.74; python_version < "3.12", which is not installed.
# apache-beam 2.56.0 requires jsonpickle<4.0.0,>=3.0.0, which is not installed.
# apache-beam 2.56.0 requires jsonschema<5.0.0,>=4.0.0, which is not installed.
# apache-beam 2.56.0 requires objsize<0.8.0,>=0.6.1, which is not installed.
# apache-beam 2.56.0 requires orjson<4,>=3.9.7, which is not installed.
# apache-beam 2.56.0 requires proto-plus<2,>=1.7.1, which is not installed.
# apache-beam 2.56.0 requires pyarrow<12.0.0,>=3.0.0, which is not installed.
# apache-beam 2.56.0 requires pyarrow-hotfix<1, which is not installed.
# apache-beam 2.56.0 requires pydot<2,>=1.2.0, which is not installed.
# apache-beam 2.56.0 requires pymongo<5.0.0,>=3.8.0, which is not installed.
# apache-beam 2.56.0 requires pytz>=2018.3, which is not installed.
# apache-beam 2.56.0 requires redis<6,>=5.0.0, which is not installed.
# apache-beam 2.56.0 requires zstandard<1,>=0.18.0, which is not installed.
# tf-models-official 2.16.0 requires gin-config, which is not installed.
# tf-models-official 2.16.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.16.0 requires immutabledict, which is not installed.
# tf-models-official 2.16.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.16.0 requires oauth2client, which is not installed.
# tf-models-official 2.16.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.16.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.16.0 requires pyyaml>=6.0.0, which is not installed.
# tf-models-official 2.16.0 requires sentencepiece, which is not installed.
# tf-models-official 2.16.0 requires seqeval, which is not installed.
# tf-models-official 2.16.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.16.0 requires tensorflow-hub>=0.6.0, which is not installed.
# tf-models-official 2.16.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.16.0 requires tensorflow-text~=2.16.1, which is not installed.

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'],'research','object_detection','builders','model_builder_tf2_test.py')
# !python {VERIFICATION_SCRIPT}
# Out:
# 2024-06-04 16:10:54.445789: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-04 16:10:55.420287: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Traceback (most recent call last):
#   File "a:\Projects\Object Detection\TFODCourse\Tensorflow\models\research\object_detection\builders\model_builder_tf2_test.py", line 24, in <module>
#     from object_detection.builders import model_builder
#   File "a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\model_builder.py", line 23, in <module>
#     from object_detection.builders import anchor_generator_builder
#   File "a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\builders\anchor_generator_builder.py", line 26, in <module>
#     from object_detection.protos import anchor_generator_pb2
#   File "a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\protos\anchor_generator_pb2.py", line 14, in <module>
#     from object_detection.protos import flexible_grid_anchor_generator_pb2 as object__detection_dot_protos_dot_flexible__grid__anchor__generator__pb2
#   File "a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\object_detection-0.1-py3.11.egg\object_detection\protos\flexible_grid_anchor_generator_pb2.py", line 36, in <module>
#     _descriptor.FieldDescriptor(
#   File "a:\Projects\Object Detection\TFODCourse\tfod\Lib\site-packages\google\protobuf\descriptor.py", line 621, in __new__
#     _message.Message._CheckCalledFromGeneratedFile()
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
# !pip uninstall tensorflow
# Out:
# ^C
